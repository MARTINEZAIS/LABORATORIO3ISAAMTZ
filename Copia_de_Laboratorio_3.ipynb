# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "/content/drive/MyDrive/CSV/atenciones_abogadas_de_las_mujeres .csv"

df = pd.read_csv(path)

edad = df["usuaria_edad"]

dist = edad.value_counts()

plt.bar(dist.index, dist.values)

plt.xlim(0,100)

plt.show()
# Out:
# <ipython-input-3-d81e215091ff>:6: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "/content/drive/MyDrive/CSV/atenciones_abogadas_de_las_mujeres .csv"

df = pd.read_csv(path)

año = df["anio_a"]

dist = año.value_counts()

plt.bar(dist.index, dist.values)

plt.xlim(2019,2022)

plt.show()
# Out:
# <ipython-input-17-b099bb81b18c>:6: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
